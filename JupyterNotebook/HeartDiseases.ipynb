# %%
from google.colab import files
uploaded = files.upload()

# %%
import pandas as pd
df = pd.read_csv('Heart Disease Dataset.csv')
pd.set_option('display.max_rows', None)  
df
# Out:
# /home/senjuti/.pyenv/versions/3.6.8/envs/env-3.6.8/lib/python3.6/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
from sklearn.svm import SVC

feature_cols = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']
x = df[feature_cols]
y = df['target']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10)
x_test
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 202   58    1   0       150   270    0        0      111      1      0.8
# 172   58    1   1       120   284    0        0      160      0      1.8
# 204   62    0   0       160   164    0        0      145      0      6.2
# 253   67    1   0       100   299    0        0      125      1      0.9
# 42    45    1   0       104   208    0        0      148      1      3.0
# 211   61    1   0       120   260    0        1      140      1      3.6
# 285   46    1   0       140   311    0        1      120      1      1.8
# 140   51    0   2       120   295    0        0      157      0      0.6
# 199   65    1   0       110   248    0        0      158      0      0.6
# 21    44    1   2       130   233    0        1      179      1      0.4
# 96    62    0   0       140   394    0        0      157      0      1.2
# 123   54    0   2       108   267    0        0      167      0      0.0
# ...

# %%
svm = SVC(kernel="linear", C=0.025) #enrollment
svm.fit(x_train, y_train) #teaching
y_pred = svm.predict(x_test) #exam
y_pred

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7419354838709677

# %%
from sklearn import model_selection

kfold = model_selection.KFold(n_splits=10, random_state=31, shuffle=True)
model =  SVC(kernel="linear")

results = model_selection.cross_val_score(model, x_train, y_train, cv=kfold)
results
# Out:
# array([0.75      , 0.82142857, 0.81481481, 0.74074074, 0.77777778,
#        0.96296296, 0.88888889, 0.88888889, 0.96296296, 0.74074074])

# %%
from joblib import dump

# dump the pipeline model
dump(svm, filename="diseaseprediction.joblib")
# Out:
# ['diseaseprediction.joblib']

# %%
from joblib import load

# load the pipeline model
pipeline = load("diseaseprediction.joblib")
pipeline.predict([[35,  0,  2,  115,  245,  0,  0,  147,  0,  0.4,  2,  0,  2]])
# Out:
# array([1])

# %%
data = {'age': '35', 'female': '0', 'CP': '2', 'trestbps': '115', 'false': '0', 'RECG': '0', 'thalach': '147', 'no': '0', 'oldpeak': '0.4', 'Slope': '2', 'CA': '0', 'THAL': '2'}
df = pd.DataFrame(data, index=[0])
df
# Out:
#   age female CP trestbps false RECG thalach no oldpeak Slope CA THAL
# 0  35      0  2      115     0    0     147  0     0.4     2  0    2

# %%
from joblib import load

# load the pipeline model
pipeline = load("diseaseprediction.joblib")
pipeline.predict([[56, 1, 0, 130, 283, 1, 0, 103, 1, 1.6, 0, 0, 3]])
# Out:
# array([0])

# %%
# 68	1	0	144	193	1	1	141	0	3.4	1	2	3	
# 44	1	0	120	169	0	1	144	1	2.8	0	0	1	
from joblib import load

# load the pipeline model
pipeline = load("diseaseprediction.joblib")
pipeline.predict([[44, 1, 0, 120, 169, 0, 1, 144, 1, 2.8, 0, 0, 1]])
# Out:
# array([0])

# %%
# 62	0	0	140	394	0	0	157	0	1.2	1	0	2	

from joblib import load

# load the pipeline model
pipeline = load("diseaseprediction.joblib")
pipeline.predict([[62, 0, 0, 140, 394, 0, 0, 157, 0, 1.2, 1, 0, 2]])
# Out:
# array([1])
